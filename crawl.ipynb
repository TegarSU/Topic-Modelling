# %%
import tweepy
import csv
import pandas as pd
import re

# %%
# consumer_key = 'mniJ4xlW8hlfvFxWyYkvm6TAm'
# consumer_secret = 'XKa1i8HfuWl925CcLajdLnmVOCMXWq4xMhLubHAzzwMqaKA6eZ'
# access_token = '3063908508-S7KI9scFpuD99aOT0iQEC1Xb7jLIjAb3zwSVVEI'
# access_token_secret = 'Bi2LnIebB7lYRkWdxMlvzvGxU8twJ8NqoQvoeVVDILSlo'
# # OAuth process, using the keys and tokens

# %%
# auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
# auth.set_access_token(access_token, access_token_secret)
# api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify = True)

# %%
# lat = "-6.265750" #latitude
# long = "106.78182" #longitude
# trends = api.trends_closest(lat, long) #search WOEID jakarta

# trends = api.trends_place(1047378) # search by WOEID, jakarta

# %%
# trends
data = trends[0] 
trends = data['trends']
trending = list() #trending
names = [trend['name'] for trend in trends]

for i in range(10):
    trending.append(names[i]) #get 10 trending

# trending  

print(trending)
# Out:
# ['#SemogaPuasaTahunIni', '#AlasanTetapHidup', '#BucinWowoCaper', '#DiskualifikasiYangCurang', '#sekolahnaiktransjakarta', 'Favorite MV', 'Sheyla', 'Mas AHY', 'Wonu', 'Partai Demokrat']

# %%
# # type(trending)
# max_tweets = 1000
# # latitide = "-6.265750" #latitude
# # longitude = "106.78182"
# # radius = "150km"
# query="Partai Demokrat"
# # for i in trending:
# searched_tweets = [status for status in tweepy.Cursor(api.search, q=query).items(max_tweets)]
# #     tweet = api.search(q, lang, locale, rpp, page, since_id, geocode, show_user)

# %%
# for i,v in enumerate(searched_tweets):
#     print(i)

# %%
# with open('topik_03.csv', 'w', encoding="utf-8",newline='') as csv_tweet:

#     fieldnames_tweet = ['id', 'user_name', 'created_at', 'text','trendings']
#     writer_tweet = csv.DictWriter(csv_tweet, fieldnames=fieldnames_tweet)
#     writer_tweet.writeheader()

#     for tweet in searched_tweets:
# #         if "http" not in tweet.text and "@" not in tweet.text:
#             #line = re.sub("[^A-Za-z]", " ", tweet.text)
#             #user_id = tweet.user.id
#         writer_tweet.writerow({
#             'id': tweet.id, 
#             'user_name': tweet.user.screen_name,
#             'created_at': tweet.created_at, 
#             'text': tweet.text,
#             'trendings': query
#             })

# %%
data1 = pd.read_csv("topik_01.csv")
data2 = pd.read_csv("topik_02.csv")
data3 = pd.read_csv("topik_03.csv")

frame = [data1,data2,data3]
data = pd.concat(frame)

data
# text = data['text'].tolist()
# Out:
#                       id        user_name           created_at  \
# 0    1123983568500400129           me_idy  2019-05-02 16:12:19
# 1    1123983419283845125    robbseptiants  2019-05-02 16:11:44
# 2    1123983321787195393     natamiayunda  2019-05-02 16:11:21
# 3    1123983291210539008     AlFathirAU__  2019-05-02 16:11:13
# 4    1123983249364090881      Feriikrnwn_  2019-05-02 16:11:03
# 5    1123983167424278530         amimidun  2019-05-02 16:10:44
# 6    1123982902260379655      RifdahFatin  2019-05-02 16:09:41
# 7    1123982843414237184       88kang_luq  2019-05-02 16:09:27
# 8    1123982552962936841     oom_gondlong  2019-05-02 16:08:17
# 9    1123982256299827200  Muhamma99729720  2019-05-02 16:07:07
# 10   1123982256157097984     bangdani1993  2019-05-02 16:07:07
# 11   1123982246543798272         Yeyen302  2019-05-02 16:07:04
# 12   1123982168097742848         intnwidi  2019-05-02 16:06:46
# 13   1123982098719809537    karinatrisha_  2019-05-02 16:06:29
# 14   1123981987667169280  melliyana_memey  2019-05-02 16:06:03
# 15   1123981946357460993      utama_aldhi  2019-05-02 16:05:53
# 16   1123981881429692418    mbambarumahan  2019-05-02 16:05:37
# 17   1123981864803479561       ramaryani_  2019-05-02 16:05:33
# 18   1123981817101594624     ketiknamague  2019-05-02 16:05:22
# 19   1123981770540683264      ilhamfadhly  2019-05-02 16:05:11
# 20   1123981529385000961          pen_sas  2019-05-02 16:04:13
# 21   1123981509172633600    Sipaa21628487  2019-05-02 16:04:09
# 22   1123981437311565825         Sumarih2  2019-05-02 16:03:51
# 23   1123981392600358912     nilakusumasr  2019-05-02 16:03:41
# 24   1123981347457048578  melliyana_memey  2019-05-02 16:03:30
# 25   1123981224765214721      aryasudarta  2019-05-02 16:03:01
# 26   1123981171606601728        fazmalika  2019-05-02 16:02:48
# 27   1123981115302273024    Sipaa21628487  2019-05-02 16:02:35
# 28   1123980830320332800      utama_aldhi  2019-05-02 16:01:27
# 29   1123980788352024583   IndraGunners16  2019-05-02 16:01:17
# ..                   ...              ...                  ...
# 749  1123734724004995073         Swag48Ls  2019-05-01 23:43:30
# 750  1123729848365658112          fiantCo  2019-05-01 23:24:08
# 751  1123718539129569281   hafizhlyansyah  2019-05-01 22:39:12
# 752  1123701676479852549      Demokrat_TV  2019-05-01 21:32:11
# 753  1123664326320017408        DoelKelor  2019-05-01 19:03:46
# 754  1123655473322909696    IndraJPiliang  2019-05-01 18:28:36
# 755  1123652674556030976       TheDjango2  2019-05-01 18:17:28
# 756  1123644599602302978     Ardi25849330  2019-05-01 17:45:23
# 757  1123629252316766208     caramelcarbs  2019-05-01 16:44:24
# 758  1123626572089479170      AlbertSolo2  2019-05-01 16:33:45
# 759  1123625979509796864      AlbertSolo2  2019-05-01 16:31:24
# 760  1123622465253457920  kimlukmanneswst  2019-05-01 16:17:26
# 761  1123621417080070144     Gie09April90  2019-05-01 16:13:16
# 762  1123618495915122689        iramady15  2019-05-01 16:01:39
# 763  1123617871299477506         yugi_nie  2019-05-01 15:59:10
# 764  1123617142056701952           gnwn_d  2019-05-01 15:56:17
# 765  1123615068703182848     voaindonesia  2019-05-01 15:48:02
# 766  1123612360973832192     CarterMangar  2019-05-01 15:37:17
# 767  1123611713092218881        Robot0212  2019-05-01 15:34:42
# 768  1123611704649117696       susenoshiu  2019-05-01 15:34:40
# 769  1123609620021256192     abdulkhaydir  2019-05-01 15:26:23
# 770  1123608869949755393  DimanJancokMiko  2019-05-01 15:23:24
# 771  1123604167933644800       MeongEmpus  2019-05-01 15:04:43
# 772  1123603982411227136        tiaraboni  2019-05-01 15:03:59
# 773  1123603363755507718  AbdulMu48035815  2019-05-01 15:01:32
# 774  1123601508052824064      HayatiIbadi  2019-05-01 14:54:09
# 775  1123601265068347394      tfq_firdaus  2019-05-01 14:53:11
# 776  1123601055122485248        NawirTola  2019-05-01 14:52:21
# 777  1123598183588741122  ElshintaBandung  2019-05-01 14:40:57
# 778  1123594133870825472      rafiumaro77  2019-05-01 14:24:51
#
#                                                   text             trendings
# 0    #SemogaPuasaTahunIni \nnggak sendiri lagi..\n\...  #SemogaPuasaTahunIni
# 1    #SemogaPuasaTahunIni bisa tahan godaan dari or...  #SemogaPuasaTahunIni
# 2    RT @gryprmna: #SemogaPuasaTahunIni kaga mikiri...  #SemogaPuasaTahunIni
# 3    #SemogaPuasaTahunIni disehatkan mental dan jas...  #SemogaPuasaTahunIni
# 4     #SemogaPuasaTahunIni bukber nya ga wacana semuaa  #SemogaPuasaTahunIni
# 5    #SemogaPuasaTahunIni #AlasanTetapHidup #BucinW...  #SemogaPuasaTahunIni
# 6    RT @septianiephie: #SemogaPuasaTahunIni aku bi...  #SemogaPuasaTahunIni
# 7            #SemogaPuasaTahunIni presiden nya baru...  #SemogaPuasaTahunIni
# 8    Gak banyak yang godain pake granita sama ngaja...  #SemogaPuasaTahunIni
# 9    #SemogaPuasaTahunIni bisa menyempurnakan agama...  #SemogaPuasaTahunIni
# 10   #SemogaPuasaTahunIni lupa sama kamu, bersikap ...  #SemogaPuasaTahunIni
# 11   #SemogaPuasaTahunIni yang disemogakan segera t...  #SemogaPuasaTahunIni
# 12   #SemogaPuasaTahunIni Dipanjangkan umurnya dise...  #SemogaPuasaTahunIni
# 13   #SemogaPuasaTahunIni bisa lebi banyak godain o...  #SemogaPuasaTahunIni
# 14   #SemogaPuasaTahunIni kalo beli kolak pisang mo...  #SemogaPuasaTahunIni
# 15   #SemogaPuasaTahunIni dapet takjil gratis selam...  #SemogaPuasaTahunIni
# 16   #SemogaPuasaTahunIni lebaran nya gak ditanya "...  #SemogaPuasaTahunIni
# 17   #SemogaPuasaTahunIni ada dua garis merah di te...  #SemogaPuasaTahunIni
# 18   Pengen ikutan ngetwit, tapi aku Kristen \n #Se...  #SemogaPuasaTahunIni
# 19   #SemogaPuasaTahunIni dijauhkan dari ojol yang ...  #SemogaPuasaTahunIni
# 20   #SemogaPuasaTahunIni bersih dari tudingan-tudi...  #SemogaPuasaTahunIni
# 21   RT @IklimaSandra: #SemogaPuasaTahunIni terhind...  #SemogaPuasaTahunIni
# 22   Lontong bakwan masih seribuan harganya #Semoga...  #SemogaPuasaTahunIni
# 23   RT @rizcyuda: #SemogaPuasaTahunIni THR nya dou...  #SemogaPuasaTahunIni
# 24   #SemogaPuasaTahunIni gak ketelatan sahur, trus...  #SemogaPuasaTahunIni
# 25   #SemogaPuasaTahunIni sirup marjan kelurin rasa...  #SemogaPuasaTahunIni
# 26   RT @rizcyuda: #SemogaPuasaTahunIni THR nya dou...  #SemogaPuasaTahunIni
# 27   RT @yogaafnd: #SemogaPuasaTahunIni\nBumi damai...  #SemogaPuasaTahunIni
# 28   #SemogaPuasaTahunIni iklan Marjan ngga bersamb...  #SemogaPuasaTahunIni
# 29                    #SemogaPuasaTahunIni bisa sidang  #SemogaPuasaTahunIni
# ..                                                 ...                   ...
# 749  Kata2_IG #QuizIG Irman Gusman untuk konvensi p...       Partai Demokrat
# 750  RT @jansen_jsp: --DEMOKRAT JUARA DI PAKPAK BHA...       Partai Demokrat
# 751  RT @RinduSBY: Berkat Bapak SBY dan dukungan pe...       Partai Demokrat
# 752  RT @RinduSBY: Berkat Bapak SBY dan dukungan pe...       Partai Demokrat
# 753  RT @jansen_jsp: --DEMOKRAT JUARA DI PAKPAK BHA...       Partai Demokrat
# 754  Data masuk hampir 50%. Sumbar II: Kursi 6.\nGe...       Partai Demokrat
# 755  @isari68 Bgmna untuk caleg2 DPR dr partai di d...       Partai Demokrat
# 756  RT @RinduSBY: Berkat Bapak SBY dan dukungan pe...       Partai Demokrat
# 757  Gewd artikel ttg tipografi yg digunakan oleh c...       Partai Demokrat
# 758  Memang benar bang Ferdinand telah mengajukan p...       Partai Demokrat
# 759  Ferdinand Hutahean di kabarkan mengundurkan di...       Partai Demokrat
# 760  RT @jansen_jsp: --DEMOKRAT JUARA DI PAKPAK BHA...       Partai Demokrat
# 761  minta jatah MPR heh..?? Sehat?? @hanumrais @Am...       Partai Demokrat
# 762  RT @jansen_jsp: --DEMOKRAT JUARA DI PAKPAK BHA...       Partai Demokrat
# 763  Biden Unggul dalam Persaingan Pemilihan Primer...       Partai Demokrat
# 764      @DidikUtomoSH @detikcom SBY, Partai Demokrat?       Partai Demokrat
# 765  Biden Unggul dalam Persaingan Pemilihan Primer...       Partai Demokrat
# 766  @FerdinandHaean2 Haahaahaaa… Saudaraku. Saya l...       Partai Demokrat
# 767  @FerdinandHaean2 Riwayat mu kini telah usai Be...       Partai Demokrat
# 768  RT @detikcom: Calon legislatif dari Partai Dem...       Partai Demokrat
# 769  @sedyautamaandin @HMuhamadDani1 Iya itu strate...       Partai Demokrat
# 770  RT @TopeRendusara: Jadi sekjen PKB saja gak be...       Partai Demokrat
# 771  RT @RinduSBY: Berkat Bapak SBY dan dukungan pe...       Partai Demokrat
# 772  RT @jansen_jsp: --DEMOKRAT JUARA DI PAKPAK BHA...       Partai Demokrat
# 773  RT @RinduSBY: Berkat Bapak SBY dan dukungan pe...       Partai Demokrat
# 774  RT @ElshintaBandung: Caleg Partai Demokrat DPR...       Partai Demokrat
# 775  RT @jansen_jsp: --DEMOKRAT JUARA DI PAKPAK BHA...       Partai Demokrat
# 776  RT @RinduSBY: Berkat Bapak SBY dan dukungan pe...       Partai Demokrat
# 777  Caleg Partai Demokrat DPR RI Dapil 2 Kab Bdg &...       Partai Demokrat
# 778  @nugrahayltr @BACHOTTT @thasyamaghfira @cinder...       Partai Demokrat
#
# [2779 rows x 5 columns]

# %%
def normalize(text):

    pattern = re.compile(r"[\n]")
    patterns = re.compile(r'\s+')
    sentence = re.sub(pattern, ' ', text)
    sentence = re.sub(patterns, ' ', sentence)

    return sentence

# %%
data['text'] = data['text'].apply(normalize)
# data.head()

# %%
df = pd.DataFrame(data=data)
df.to_csv("C:/Users/USER/Downloads/tegar nitip/SMT 8/AMS/FP/all.csv", sep=',',index=False)

# %%
data = pd.read_csv("all.csv")
data.head()
# Out:
#                     id      user_name           created_at  \
# 0  1123983568500400129  me_idy         2019-05-02 16:12:19
# 1  1123983419283845125  robbseptiants  2019-05-02 16:11:44
# 2  1123983321787195393  natamiayunda   2019-05-02 16:11:21
# 3  1123983291210539008  AlFathirAU__   2019-05-02 16:11:13
# 4  1123983249364090881  Feriikrnwn_    2019-05-02 16:11:03
#
#                                                                                                                           text  \
# 0  #SemogaPuasaTahunIni nggak sendiri lagi.. Tapi, itu cuma ekspetasi 😕 Kenyataannya... Masih JOMBLO!! https://t.co/3TcbJrO8M4
# 1  #SemogaPuasaTahunIni bisa tahan godaan dari orng², liar, nakal, brutal membuat orang menjadi gempar.
# 2  RT @gryprmna: #SemogaPuasaTahunIni kaga mikirin people we can't have terooos
# 3  #SemogaPuasaTahunIni disehatkan mental dan jasmani, berubah sedikit ke arah yang lebih baik. Aaminn
# 4  #SemogaPuasaTahunIni bukber nya ga wacana semuaa
#
#               trendings
# 0  #SemogaPuasaTahunIni
# 1  #SemogaPuasaTahunIni
# 2  #SemogaPuasaTahunIni
# 3  #SemogaPuasaTahunIni
# 4  #SemogaPuasaTahunIni
